# %%
from models.attention.rnn import GRUv2,LSTMv2
import torch
# Out:
# c:\Users\tekju\Desktop\nlp_scratch\models\attention\rnn.py:269: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer is 0:

# %%
GRUv2(27,128,4)(torch.rand(3,27))
# Out:
# tensor([[2.5538e-02, 9.9940e-01, 7.2809e-01, 1.3569e-01, 5.0429e-01, 9.9247e-01,
#          2.7960e-01, 2.4604e-01, 4.0633e-01, 9.3353e-01, 1.6634e-03, 5.3933e-02,
#          9.7277e-01, 2.9770e-01, 9.2261e-01, 4.4703e-01, 1.8502e-01, 7.4327e-02,
#          6.6776e-03, 1.0368e-07, 4.8280e-01, 4.8757e-01, 8.4716e-01, 1.4617e-03,
#          5.8047e-02, 7.9677e-02, 1.2256e-03, 1.3060e-01, 9.9529e-01, 5.5197e-01,
#          1.0398e-04, 1.0477e-03, 9.9370e-01, 8.6510e-03, 1.7704e-01, 8.5858e-01,
#          1.3391e-03, 4.9255e-01, 4.2772e-02, 5.6309e-01, 8.5196e-02, 9.5907e-01,
#          1.3925e-01, 8.2913e-01, 3.0030e-01, 6.1065e-01, 9.7608e-01, 9.2221e-01,
#          1.4314e-01, 9.5532e-01, 1.9301e-01, 4.6669e-02, 2.4674e-01, 7.7142e-03,
#          7.2644e-01, 5.4275e-01, 2.2370e-01, 1.6447e-01, 8.5118e-01, 2.4559e-02,
#          6.3858e-01, 5.2699e-01, 3.1931e-02, 6.5340e-01, 4.1662e-01, 4.1366e-02,
#          2.2224e-02, 9.6740e-01, 9.9392e-01, 2.6575e-01, 4.7987e-02, 3.0067e-01,
# ...

# %%
LSTMv2(27,8,2)(torch.rand(3,27))
# Out:
# tensor([[0.9950, 0.9949, 0.9949, 0.9949, 0.9950, 0.9949, 0.9950, 0.9949],
#         [0.9941, 0.9936, 0.9938, 0.9940, 0.9941, 0.9943, 0.9940, 0.9938]],
#        grad_fn=<StackBackward0>)
